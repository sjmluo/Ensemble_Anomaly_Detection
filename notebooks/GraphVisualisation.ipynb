# %%
import networkx as nx
import json
# %config Completer.use_jedi = False

# %%
with open('../data/YelpChi/Yelp_graph_data.json','r') as f:
    data = json.load(f)

# %%
data['links']
# Out:
# [{'rating': 0,
#   'label': 1,
#   'date': 'None',
#   'prior': 0.35048557119705304,
#   'types': 'review',
#   'source': '201',
#   'target': '0'},
#  {'rating': 0,
#   'label': 1,
#   'date': 'None',
#   'prior': 0.07276221222389068,
#   'types': 'review',
#   'source': '202',
#   'target': '0'},
#  {'rating': 1,
#   'label': 1,
#   'date': 'None',
#   'prior': 0.35048557119705304,
#   'types': 'review',
#   'source': '203',
#   'target': '0'},
#  {'rating': 0,
#   'label': 1,
#   'date': 'None',
#   'prior': 0.35048557119705304,
#   'types': 'review',
#   'source': '204',
#   'target': '0'},
#  {'rating': 0,
#   'label': 1,
#   'date': 'None',
#   'prior': 0.07276221222389068,
#   'types': 'review',
#   'source': '205',
#   'target': '0'},
#  {'rating': 1,
#   'label': 1,
#   'date': 'None',
#   'prior': 0.35048557119705304,
#   'types': 'review',
#   'source': '206',
#   'target': '0'},
#  {'rating': 0,
#   'label': 1,
#   'date': 'None',
#   'prior': 0.16487184096730545,
# ...

# %%
graph = networkx.readwrite.json_graph.node_link_graph(data)

# %%
graph.number_of_nodes()
# Out:
# 38264

# %%
nx.draw(graph, node_size=15)

# %%
g1=graph.subgraph(['0','1','2','3','4','5','201','236','213'])

# %%
nx.draw(g1, node_size=15)

# %%
graph.edges()
# Out:
# EdgeView([('201', '0'), ('202', '0'), ('203', '0'), ('204', '0'), ('205', '0'), ('206', '0'), ('207', '1'), ('208', '1'), ('209', '1'), ('210', '1'), ('211', '1'), ('211', '36'), ('211', '124'), ('212', '1'), ('213', '1'), ('214', '1'), ('214', '67'), ('215', '1'), ('216', '1'), ('216', '51'), ('216', '108'), ('217', '1'), ('218', '1'), ('219', '1'), ('220', '1'), ('221', '1'), ('222', '1'), ('223', '1'), ('224', '1'), ('225', '1'), ('226', '1'), ('227', '1'), ('227', '35'), ('228', '1'), ('229', '1'), ('229', '139'), ('230', '1'), ('231', '1'), ('232', '1'), ('233', '1'), ('234', '1'), ('234', '154'), ('235', '1'), ('236', '1'), ('237', '1'), ('238', '1'), ('238', '52'), ('238', '74'), ('239', '1'), ('239', '38'), ('239', '40'), ('239', '124'), ('239', '135'), ('240', '1'), ('241', '1'), ('242', '1'), ('243', '1'), ('244', '1'), ('245', '1'), ('246', '1'), ('246', '18'), ('246', '20'), ('247', '1'), ('247', '149'), ('248', '1'), ('249', '1'), ('249', '53'), ('250', '1'), ('250', '14
# ...
